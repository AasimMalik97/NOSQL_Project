# %%
# Install the dependencies

from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
# Get the colab otebook IP
username = ""
password = ""
cluster_url = ""

uri = f"mongodb+srv://{username}:{password}@{cluster_url}/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['movie_recommendation']
collection = db['movies']


# Insert sample data
movies = [
    {
        "_id": "1",
        "title": "Inception",
        "description": "A skilled thief is offered a chance to have his past crimes forgiven if he can implant another person's idea into a target's subconscious.",
        "genre": ["Sci-Fi", "Thriller"],
        "cast": ["Leonardo DiCaprio", "Joseph Gordon-Levitt"],
        "release_date": "2010-07-16",
        "reviews": [
            {"user_id": "101", "rating": 5, "comment": "Mind-blowing!"},
            {"user_id": "102", "rating": 4, "comment": "Great movie, but complex."}
        ]
    },
    {
        "_id": "2",
        "title": "Interstellar",
        "description": "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.",
        "genre": ["Sci-Fi", "Adventure"],
        "cast": ["Matthew McConaughey", "Anne Hathaway"],
        "release_date": "2014-11-07",
        "reviews": [
            {"user_id": "103", "rating": 5, "comment": "Amazing visuals and story!"},
            {"user_id": "101", "rating": 4.5, "comment": "Emotionally powerful."}
        ]
    },
    {
        "_id": "3",
        "title": "The Dark Knight",
        "description": "Batman faces the Joker, a criminal mastermind intent on plunging Gotham City into anarchy.",
        "genre": ["Action", "Crime", "Drama"],
        "cast": ["Christian Bale", "Heath Ledger"],
        "release_date": "2008-07-18",
        "reviews": [
            {"user_id": "104", "rating": 5, "comment": "An absolute masterpiece!"},
            {"user_id": "105", "rating": 4.5, "comment": "Heath Ledger's performance was incredible."}
        ]
    },
    {
        "_id": "4",
        "title": "Avatar",
        "description": "A paraplegic Marine is sent to the moon Pandora on a unique mission but becomes torn between following orders and protecting the world he feels is his home.",
        "genre": ["Sci-Fi", "Adventure"],
        "cast": ["Sam Worthington", "Zoe Saldana"],
        "release_date": "2009-12-18",
        "reviews": [
            {"user_id": "106", "rating": 4, "comment": "Visually stunning!"},
            {"user_id": "102", "rating": 3.5, "comment": "Predictable but visually groundbreaking."}
        ]
    },
    {
        "_id": "5",
        "title": "The Matrix",
        "description": "A computer hacker learns about the true nature of reality and his role in the war against its controllers.",
        "genre": ["Sci-Fi", "Action"],
        "cast": ["Keanu Reeves", "Laurence Fishburne"],
        "release_date": "1999-03-31",
        "reviews": [
            {"user_id": "107", "rating": 5, "comment": "Changed the way we think about movies."},
            {"user_id": "101", "rating": 4.5, "comment": "Still one of the best sci-fi films ever."}
        ]
    },
    {
        "_id": "6",
        "title": "Pulp Fiction",
        "description": "The lives of two mob hitmen, a boxer, a gangster's wife, and a pair of diner bandits intertwine in four tales of violence and redemption.",
        "genre": ["Crime", "Drama"],
        "cast": ["John Travolta", "Uma Thurman"],
        "release_date": "1994-10-14",
        "reviews": [
            {"user_id": "108", "rating": 5, "comment": "Iconic and timeless!"},
            {"user_id": "102", "rating": 4.5, "comment": "Tarantino's masterpiece."}
        ]
    },
    {
        "_id": "7",
        "title": "Forrest Gump",
        "description": "The story of an Alabama man with a low IQ who lives an extraordinary life, witnessing and influencing historical events.",
        "genre": ["Drama", "Romance"],
        "cast": ["Tom Hanks", "Robin Wright"],
        "release_date": "1994-07-06",
        "reviews": [
            {"user_id": "109", "rating": 5, "comment": "Heartwarming and unforgettable."},
            {"user_id": "110", "rating": 4.5, "comment": "Tom Hanks at his best."}
        ]
    },
    {
        "_id": "8",
        "title": "The Shawshank Redemption",
        "description": "Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.",
        "genre": ["Drama"],
        "cast": ["Tim Robbins", "Morgan Freeman"],
        "release_date": "1994-09-22",
        "reviews": [
            {"user_id": "111", "rating": 5, "comment": "Incredibly moving and inspiring."},
            {"user_id": "103", "rating": 4.5, "comment": "A timeless classic."}
        ]
    },
    {
        "_id": "9",
        "title": "The Godfather",
        "description": "The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.",
        "genre": ["Crime", "Drama"],
        "cast": ["Marlon Brando", "Al Pacino"],
        "release_date": "1972-03-24",
        "reviews": [
            {"user_id": "101", "rating": 5, "comment": "A masterpiece in every sense."},
            {"user_id": "112", "rating": 5, "comment": "Unparalleled storytelling."}
        ]
    },
    {
        "_id": "10",
        "title": "The Lord of the Rings: The Return of the King",
        "description": "The final confrontation between the forces of good and evil fighting for control of Middle-earth.",
        "genre": ["Adventure", "Fantasy"],
        "cast": ["Elijah Wood", "Ian McKellen"],
        "release_date": "2003-12-17",
        "reviews": [
            {"user_id": "113", "rating": 5, "comment": "An epic conclusion!"},
            {"user_id": "104", "rating": 4.5, "comment": "Visually stunning and emotional."}
        ]
    },
    {
        "_id": "11",
        "title": "Gladiator",
        "description": "A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family.",
        "genre": ["Action", "Drama"],
        "cast": ["Russell Crowe", "Joaquin Phoenix"],
        "release_date": "2000-05-05",
        "reviews": [
            {"user_id": "105", "rating": 5, "comment": "Russell Crowe's best performance."},
            {"user_id": "114", "rating": 4.5, "comment": "A thrilling story of revenge."}
        ]
    },
    {
        "_id": "12",
        "title": "The Lion King",
        "description": "Lion prince Simba flees his kingdom after the murder of his father but returns to reclaim his throne.",
        "genre": ["Animation", "Adventure", "Drama"],
        "cast": ["Matthew Broderick", "Jeremy Irons"],
        "release_date": "1994-06-15",
        "reviews": [
            {"user_id": "115", "rating": 5, "comment": "Childhood nostalgia!"},
            {"user_id": "116", "rating": 4.5, "comment": "A timeless Disney classic."}
        ]
    },
    {
        "_id": "13",
        "title": "The Avengers",
        "description": "Earth's mightiest heroes must come together and learn to fight as a team to stop Loki and his alien army.",
        "genre": ["Action", "Adventure", "Sci-Fi"],
        "cast": ["Robert Downey Jr.", "Chris Evans"],
        "release_date": "2012-05-04",
        "reviews": [
            {"user_id": "101", "rating": 4.5, "comment": "Superhero team-up done right!"},
            {"user_id": "103", "rating": 4, "comment": "Great action sequences."}
        ]
    },
    {
        "_id": "14",
        "title": "Titanic",
        "description": "A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious ill-fated R.M.S. Titanic.",
        "genre": ["Drama", "Romance"],
        "cast": ["Leonardo DiCaprio", "Kate Winslet"],
        "release_date": "1997-12-19",
        "reviews": [
            {"user_id": "102", "rating": 5, "comment": "An emotional rollercoaster."},
            {"user_id": "104", "rating": 4.5, "comment": "Beautifully made and heartbreaking."}
        ]
    },
    {
        "_id": "15",
        "title": "Jurassic Park",
        "description": "During a preview tour, a theme park suffers a major power breakdown that allows its cloned dinosaur exhibits to run amok.",
        "genre": ["Adventure", "Sci-Fi"],
        "cast": ["Sam Neill", "Laura Dern"],
        "release_date": "1993-06-11",
        "reviews": [
            {"user_id": "105", "rating": 5, "comment": "A groundbreaking sci-fi adventure."},
            {"user_id": "112", "rating": 4.5, "comment": "Dinosaurs never looked so real."}
        ]
    },
    {
        "_id": "16",
        "title": "Star Wars: Episode IV - A New Hope",
        "description": "Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, and two droids to save the galaxy.",
        "genre": ["Action", "Adventure", "Fantasy"],
        "cast": ["Mark Hamill", "Harrison Ford"],
        "release_date": "1977-05-25",
        "reviews": [
            {"user_id": "115", "rating": 5, "comment": "The force is strong with this one."},
            {"user_id": "101", "rating": 4.5, "comment": "A classic that started it all."}
        ]
    },
]

collection.insert_many(movies)
# Out:
# InsertManyResult(['1', '2'], acknowledged=True)

# %%
# Query sample data
# Find all Sci-Fi movies
sci_fi_movies = collection.find({"genre": "Sci-Fi"})
for movie in sci_fi_movies:
    print(movie)
# Out:
# {'_id': '1', 'title': 'Inception', 'description': "A skilled thief is offered a chance to have his past crimes forgiven if he can implant another person's idea into a target's subconscious.", 'genre': ['Sci-Fi', 'Thriller'], 'cast': ['Leonardo DiCaprio', 'Joseph Gordon-Levitt'], 'release_date': '2010-07-16', 'reviews': [{'user_id': '101', 'rating': 5, 'comment': 'Mind-blowing!'}, {'user_id': '102', 'rating': 4, 'comment': 'Great movie, but complex.'}]}
# {'_id': '2', 'title': 'Interstellar', 'description': "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.", 'genre': ['Sci-Fi', 'Adventure'], 'cast': ['Matthew McConaughey', 'Anne Hathaway'], 'release_date': '2014-11-07', 'reviews': [{'user_id': '103', 'rating': 5, 'comment': 'Amazing visuals and story!'}, {'user_id': '104', 'rating': 4.5, 'comment': 'Emotionally powerful.'}]}
